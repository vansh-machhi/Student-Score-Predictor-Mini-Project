# %% [markdown]
# # Student Score Predictor

# %% [markdown]
# Goal: Predict a student's exam score based on:
# - Study hours
# - Sleep hours
# - Number of practice tests

# %%
# Step 1: Load Libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Step 2: Create Dataset
data = pd.DataFrame({
    'study_hours': [2, 3, 4, 5, 6, 7],
    'sleep_hours': [7, 6, 8, 5, 7, 6],
    'practice_tests': [1, 2, 2, 3, 3, 4],
    'score': [50, 55, 65, 70, 78, 85]
})

print("Dataset:")
print(data)

# Step 3: Split Features & Target
X = data[['study_hours', 'sleep_hours', 'practice_tests']]
y = data['score']

# Step 4: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Step 5: Train Linear Regression Model
model = LinearRegression()
model.fit(X_train, y_train)

print("\nModel trained successfully!")

# Step 6: Evaluate Model
r2_score = model.score(X_test, y_test)
print("Model Accuracy (R² score):", r2_score)

# ✅ Step 7: Take User Input
print("\nEnter Student Details for Prediction:")

study = float(input("Enter Study Hours: "))
sleep = float(input("Enter Sleep Hours: "))
tests = float(input("Enter Practice Tests Count: "))

# Step 8: Make Custom Prediction
custom_prediction = model.predict([[study, sleep, tests]])

print("\nPredicted Score:", round(custom_prediction[0], 2))

# Step 9: Visualization
plt.scatter(data['study_hours'], data['score'])

plt.plot(
    data['study_hours'],
    model.predict(data[['study_hours', 'sleep_hours', 'practice_tests']]),
    linestyle='dashed'
)

plt.xlabel("Study Hours")
plt.ylabel("Score")
plt.title("Study Hours vs Score Prediction")
plt.show()
# Out:
# Dataset:
#    study_hours  sleep_hours  practice_tests  score
# 0            2            7               1     50
# 1            3            6               2     55
# 2            4            8               2     65
# 3            5            5               3     70
# 4            6            7               3     78
# 5            7            6               4     85
#
# Model trained successfully!
# Model Accuracy (R² score): 0.6800000000000046
#
# Enter Student Details for Prediction:
# Enter Study Hours: 6
# Enter Sleep Hours: 6
# Enter Practice Tests Count: 2
#
# Predicted Score: 75.0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
